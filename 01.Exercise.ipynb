# %% [markdown]
# # 01 Python プログラミングの基本: Fundamentals of Python Programming

# %% [markdown]
# ## 課題
#
# $a = .45, b = 3.1$として、以下の計算を行うプログラムを作成し、結果を表示しなさい。
#
# Create a program that performs the following calculations with $a = .45$ and $b = 3.1$, and displays the results.
#
# $$a + b, a - b, a * b, a / b, a^2$$

# %% [markdown]
# ## 課題
# 以下の計算を行うプログラムを作成し、結果を表示しなさい。
# Create a program that performs the following calculations and displays the results.
# $$
# \begin{align*}
# s_1 &=\sum_{i=1}^{10} i \\
# s_2 &=\sum_{i=1}^{10} i^2 \\
# s_3 &=\sum_{i=1}^{10} (0.1)^i
# \end{align*}
# $$

# %% [markdown]
# ## 課題
# ネピア数$e$を求めるための式の一つに、以下のような極限がある。
# $$e = \lim_{n \to \infty} \left(1 + \frac{1}{n}\right)^n$$
# $n$が大きくなるにつれて$\left(1 + \frac{1}{n}\right)^n$がどのように変化するかを計算し、$e$に近づいていく様子を確認するプログラムを作成しなさい。
# なお、$e$の値は、`math.e`で確認できる。
#
# There is a limit that can be used to calculate the value of the mathematical constant $e$:
# $$e = \lim_{n \to \infty} \left(1 + \frac{1}{n}\right)^n$$
# Create a program that calculates $\left(1 + \frac{1}{n}\right)^n$ for increasing values of $n$ and observes how it approaches $e$.
# Note that the value of $e$ can be checked using `math.e`.

# %%
import math
