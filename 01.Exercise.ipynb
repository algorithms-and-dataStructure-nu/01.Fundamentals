# %% [markdown]
# # 01 Python プログラミングの基本: Fundamentals of Python Programming

# %%
# 学籍番号: 
# 氏名:

# %% [markdown]
# ## 課題
#
# $a = 15, b = 4$として、以下の計算を行うプログラムを作成し、結果を表示しなさい。
#
# Create a program that performs the following calculations with $a = 15$ and $b = 4$, and displays the results.
#
# $$a + b, a - b, a * b, a / b, a \% b$$

# %% [markdown]
# ## 課題
# 1から10までの整数を二乗しながら加算した結果を表示するプログラムを作成しなさい。
#
# Create a program that calculates and displays the sum of the squares of integers from 1 to 10.
